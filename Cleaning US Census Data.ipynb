# %% [markdown]
# # Cleaning US Census Data

# %% [markdown]
# You just got hired as a Data Analyst at the Census Bureau, which collects census data and creates interesting visualizations and insights from it.
#
# The person who had your job before you left you all the data they had for the most recent census. It is in multiple `csv` files. They didn't use pandas, they would just look through these `csv` files manually whenever they wanted to find something. Sometimes they would copy and paste certain numbers into Excel to make charts.
#
# The thought of it makes you shiver. This is not scalable or repeatable.
#
# Your boss wants you to make some scatterplots and histograms by the end of the day. Can you get this data into `pandas` and into reasonable shape so that you can make these histograms?

# %% [markdown]
# ## Inspect the Data!

# %% [markdown]
# 1. The first visualization your boss wants you to make is a scatterplot that shows average income in a state vs proportion of women in that state.
#
#    Open some of the census `csv` files that came with the kit you downloaded. How are they named? What kind of information do they hold? Will they help us make this graph?

# %%
import csv
with open('states0.csv', newline= '') as f:
    reader = csv.reader(f)
    for row in reader:
        print(row)
with open('states1.csv', newline= '') as f:
    reader = csv.reader(f)
    for row in reader:
        print(row)
with open('states2.csv', newline= '') as f:
    reader = csv.reader(f)
    for row in reader:
        print(row)
# Out:
# ['\ufeff', 'State', 'TotalPop', 'Hispanic', 'White', 'Black', 'Native', 'Asian', 'Pacific', 'Income', 'GenderPop']
# ['0', 'Alabama', '4830620', '3.75%', '61.88%', '31.25%', '0.45%', '1.05%', '0.03%', '$43,296.36 ', '2341093M_2489527F']
# ['1', 'Alaska', '733375', '5.91%', '60.91%', '2.85%', '16.39%', '5.45%', '1.06%', '$70,354.74 ', '384160M_349215F']
# ['2', 'Arizona', '6641928', '29.57%', '57.12%', '3.85%', '4.36%', '2.88%', '0.17%', '$54,207.82 ', '3299088M_3342840F']
# ['3', 'Arkansas', '2958208', '6.22%', '71.14%', '18.97%', '0.52%', '1.14%', '0.15%', '$41,935.63 ', '1451913M_1506295F']
# ['4', 'California', '38421464', '37.29%', '40.22%', '5.68%', '0.41%', '13.05%', '0.35%', '$67,264.78 ', '19087135M_19334329F']
# ['5', 'Colorado', '5278906', '20.78%', '69.90%', '3.55%', '0.57%', '2.66%', '', '$64,657.80 ', '2648667M_2630239F']
# ['\ufeff', 'State', 'TotalPop', 'Hispanic', 'White', 'Black', 'Native', 'Asian', 'Pacific', 'Income', 'GenderPop']
# ...

# %% [markdown]
# 2. It will be easier to inspect this data once we have it in a DataFrame. You can't even call `.head()` on these `csv`s! How are you supposed to read them?
#
#    Using `glob`, loop through the census files available and load them into DataFrames. Then, concatenate all of those DataFrames together into one DataFrame, called something like `us_census`.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob

files = glob.glob("states[0-9].csv")

df_list = []
for file in files:
    data = pd.read_csv(file)
    df_list.append(data)

us_census = pd.concat(df_list)
print(us_census.head(5))
# Out:
#    Unnamed: 0           State  TotalPop Hispanic   White   Black Native  \
# 0           0    Rhode Island   1053661   13.36%  74.33%   5.68%  0.35%
# 1           1  South Carolina   4777576    5.06%  62.89%  28.75%  0.29%
# 2           2    South Dakota    843190    3.24%  82.50%   1.42%  9.42%
# 3           3       Tennessee   6499615    4.72%  73.49%  18.28%  0.23%
# 4           4           Texas  26538614   38.05%  44.69%  11.65%  0.26%
#
#    Asian Pacific       Income            GenderPop
# 0  3.25%   0.04%  $59,125.27       510388M_543273F
# 1  1.25%   0.05%  $46,296.81     2322409M_2455167F
# 2  1.02%   0.04%  $51,805.41       423477M_419713F
# 3  1.41%   0.04%  $47,328.08     3167756M_3331859F
# 4  3.67%   0.07%  $55,874.52   13171316M_13367298F

# %% [markdown]
# 3. Look at the `.columns` and the `.dtypes` of the `us_census` DataFrame. Are those datatypes going to hinder you as you try to make histograms?
#
# A: There is an "Unamed" column and the data types for % of pop, income, and GenderPop are objects, not floats/int.

# %%
print(us_census.columns)
print(us_census.dtypes)
# Out:
# Index(['Unnamed: 0', 'State', 'TotalPop', 'Hispanic', 'White', 'Black',
#        'Native', 'Asian', 'Pacific', 'Income', 'GenderPop'],
#       dtype='object')
# Unnamed: 0     int64
# State         object
# TotalPop       int64
# Hispanic      object
# White         object
# Black         object
# Native        object
# Asian         object
# Pacific       object
# Income        object
# GenderPop     object
# dtype: object

# %% [markdown]
# 4. Look at the `head()` of the DataFrame so that you can understand why some of these `dtypes` are objects instead of integers or floats.
#
#    Start to make a plan for how to convert these columns into the right types for manipulation.

# %%
us_census.head()
# Out:
#    Unnamed: 0           State  TotalPop Hispanic   White   Black Native  \
# 0           0    Rhode Island   1053661   13.36%  74.33%   5.68%  0.35%
# 1           1  South Carolina   4777576    5.06%  62.89%  28.75%  0.29%
# 2           2    South Dakota    843190    3.24%  82.50%   1.42%  9.42%
# 3           3       Tennessee   6499615    4.72%  73.49%  18.28%  0.23%
# 4           4           Texas  26538614   38.05%  44.69%  11.65%  0.26%
#
#    Asian Pacific       Income            GenderPop
# 0  3.25%   0.04%  $59,125.27       510388M_543273F
# 1  1.25%   0.05%  $46,296.81     2322409M_2455167F
# 2  1.02%   0.04%  $51,805.41       423477M_419713F
# 3  1.41%   0.04%  $47,328.08     3167756M_3331859F
# 4  3.67%   0.07%  $55,874.52   13171316M_13367298F

# %% [markdown]
# ## Regex to the Rescue

# %% [markdown]
# 5. Use regex to turn the `Income` column into a format that is ready for conversion into a numerical type.

# %%
for i in range(len(us_census.Income)):
    string = str(us_census.Income.iat[i])
    replace_dollar_sign = string.replace('$','')
    replace_comma = replace_dollar_sign.replace(',', '')
    us_census.Income.iat[i] = replace_comma

us_census.Income = pd.to_numeric(us_census.Income)
us_census.head()
# Out:
#    Unnamed: 0           State  TotalPop Hispanic   White   Black Native  \
# 0           0    Rhode Island   1053661   13.36%  74.33%   5.68%  0.35%
# 1           1  South Carolina   4777576    5.06%  62.89%  28.75%  0.29%
# 2           2    South Dakota    843190    3.24%  82.50%   1.42%  9.42%
# 3           3       Tennessee   6499615    4.72%  73.49%  18.28%  0.23%
# 4           4           Texas  26538614   38.05%  44.69%  11.65%  0.26%
#
#    Asian Pacific    Income            GenderPop
# 0  3.25%   0.04%  59125.27      510388M_543273F
# 1  1.25%   0.05%  46296.81    2322409M_2455167F
# 2  1.02%   0.04%  51805.41      423477M_419713F
# 3  1.41%   0.04%  47328.08    3167756M_3331859F
# 4  3.67%   0.07%  55874.52  13171316M_13367298F

# %% [markdown]
# 6. Look at the `GenderPop` column. We are going to want to separate this into two columns, the `Men` column, and the `Women` column.
#
#    Split the column into those two new columns using `str.split` and separating out those results.

# %%
us_census['genpop_split'] = us_census.GenderPop.str.split('_')
us_census['Men'] = us_census.genpop_split.str.get(0)
us_census['Women'] = us_census.genpop_split.str.get(1)

us_census.drop('genpop_split', inplace=True, axis=1)
us_census.drop('GenderPop', inplace=True, axis=1)

us_census.head()
# Out:
#    Unnamed: 0           State  TotalPop Hispanic   White   Black Native  \
# 0           0    Rhode Island   1053661   13.36%  74.33%   5.68%  0.35%
# 1           1  South Carolina   4777576    5.06%  62.89%  28.75%  0.29%
# 2           2    South Dakota    843190    3.24%  82.50%   1.42%  9.42%
# 3           3       Tennessee   6499615    4.72%  73.49%  18.28%  0.23%
# 4           4           Texas  26538614   38.05%  44.69%  11.65%  0.26%
#
#    Asian Pacific    Income        Men      Women
# 0  3.25%   0.04%  59125.27    510388M    543273F
# 1  1.25%   0.05%  46296.81   2322409M   2455167F
# 2  1.02%   0.04%  51805.41    423477M    419713F
# 3  1.41%   0.04%  47328.08   3167756M   3331859F
# 4  3.67%   0.07%  55874.52  13171316M  13367298F

# %% [markdown]
# 7. Convert both of the columns into numerical datatypes.
#
#    There is still an `M` or an `F` character in each entry! We should remove those before we convert.

# %%
def remove_gen_lettr(column):
    for i in range(len(column)):
        string = str(column.iat[i])
        if 'M' in string:
            replace = string.replace('M', '')
        else:
            replace = string.replace('F', '')
        column.iat[i] = replace

remove_gen_lettr(us_census['Men'])
remove_gen_lettr(us_census['Women'])

us_census['Men'] = pd.to_numeric(us_census['Men'])
us_census['Women'] = pd.to_numeric(us_census['Women'])

us_census.dtypes
# Out:
# Unnamed: 0      int64
# State          object
# TotalPop        int64
# Hispanic       object
# White          object
# Black          object
# Native         object
# Asian          object
# Pacific        object
# Income        float64
# Men             int64
# Women         float64
# dtype: object

# %% [markdown]
# 8. Now you should have the columns you need to make the graph and make sure your boss does not slam a ruler angrily on your desk because you've wasted your whole day cleaning your data with no results to show!
#
#    Use matplotlib to make a scatterplot!
#
#    ```py
#    plt.scatter(the_women_column, the_income_column)
#    ```
#
#    Remember to call `plt.show()` to see the graph!

# %%
plt.scatter(us_census.Women, us_census.Income, c='magenta')
plt.title("Scatter Plot of Income vs. Number of Women per State")
plt.xlabel("Population of Women per State")
plt.ylabel("Income (in US Dollars)")
plt.show()
plt.clf()

# %% [markdown]
# 9. You want to double check your work. You know from experience that these monstrous csv files probably have `nan` values in them! Print out your column with the number of women per state to see.
#
#    We can fill in those `nan`s by using pandas' `.fillna()` function.
#
#    You have the `TotalPop` per state, and you have the `Men` per state. As an estimate for the `nan` values in the `Women` column, you could use the `TotalPop` of that state minus the `Men` for that state.
#
#    Print out the `Women` column after filling the `nan` values to see if it worked!

# %%
us_census = us_census.fillna(value={'Women':us_census['TotalPop']- us_census['Men']})

us_census['Women']
# Out:
# 0      543273.0
# 1     2455167.0
# 2      419713.0
# 3     3331859.0
# 4    13367298.0
# 5     1444150.0
# 0     1444150.0
# 1      318031.0
# 2     4195682.0
# 3     3497739.0
# 4      937789.0
# 5     2890732.0
# 0     3057895.0
# 1     3455936.0
# 2     5038598.0
# 3     2727005.0
# 4     1536358.0
# 5     3081445.0
# 0     3081445.0
# 1      504536.0
# 2      939759.0
# 3     1390901.0
# 4      670717.0
# 5     4561386.0
# 0     5913084.0
# 1     1942789.0
# 2     1990780.0
# 3     6534215.0
# 4     1869213.0
# 5      543273.0
# 0     4561386.0
# 1     1051703.0
# 2    10131373.0
# 3     5049925.0
# 4      353677.0
# 5     5913084.0
# 0     5123362.0
# 1      696428.0
# 2      806083.0
# 3     6556862.0
# 4     3333382.0
# 5     1558931.0
# 0     1558931.0
# 1     1453125.0
# 2     2233145.0
# 3     2364097.0
# 4      679019.0
# 5     3057895.0
# 0     2630239.0
# 1     1841615.0
# 2      478041.0
# 3      340810.0
# 4    10045763.0
# 5     5123362.0
# 0     2489527.0
# ...

# %% [markdown]
# 10. We forgot to check for duplicates! Use `.duplicated()` on your `census` DataFrame to see if we have duplicate rows in there.

# %%
us_census.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# dtype: bool

# %% [markdown]
# 11. Drop those duplicates using the `.drop_duplicates()` function.

# %%
us_census.drop_duplicates(subset = us_census.columns[1:])
# Out:
#    Unnamed: 0                 State  TotalPop Hispanic   White   Black  \
# 0           0          Rhode Island   1053661   13.36%  74.33%   5.68%
# 1           1        South Carolina   4777576    5.06%  62.89%  28.75%
# 2           2          South Dakota    843190    3.24%  82.50%   1.42%
# 3           3             Tennessee   6499615    4.72%  73.49%  18.28%
# 4           4                 Texas  26538614   38.05%  44.69%  11.65%
# 5           5                  Utah   2903379   13.47%  79.41%   1.02%
# 1           1               Vermont    626604    1.61%  93.98%   0.98%
# 2           2              Virginia   8256630    8.01%  63.27%  20.18%
# 3           3            Washington   6985464   11.14%  72.04%   3.38%
# 4           4         West Virginia   1851420    1.29%  92.18%   3.66%
# 5           5             Wisconsin   5742117    6.68%  79.86%   8.20%
# 0           0              Maryland   5930538    8.47%  52.68%  30.68%
# ...

# %% [markdown]
# 12. Make the scatterplot again. Now, it should be perfect! Your job is secure, for now.

# %%
plt.scatter(us_census.Women, us_census.Income, c='magenta')
plt.title("Scatter Plot of Income vs. Number of Women per State")
plt.xlabel("Population of Women per State")
plt.ylabel("Income (in US Dollars)")
plt.show()
plt.clf()

# %% [markdown]
# ## Histogram of Races

# %% [markdown]
# 13. Now your boss wants you to make a bunch of histograms out of the race data that you have. Look at the `.columns` again to see what the race categories are.

# %%
us_census.columns
# Out:
# Index(['Unnamed: 0', 'State', 'TotalPop', 'Hispanic', 'White', 'Black',
#        'Native', 'Asian', 'Pacific', 'Income', 'Men', 'Women'],
#       dtype='object')

# %% [markdown]
# 14. Try to make a histogram for each one!
#
#     You will have to get the columns into the numerical format, and those percentage signs will have to go.
#
#     Don't forget to fill the `nan` values with something that makes sense! You probably dropped the duplicate rows when making your last graph, but it couldn't hurt to check for duplicates again.

# %%
def remove_pct(column):
    for i in range(len(column)):
        string = str(column.iat[i])
        replace = string.replace('%', '')
        if replace == "nan":
            replace = ""
        column.iat[i] = replace

for race in us_census[['Hispanic', 'White', 'Black', 'Native', 'Asian', 'Pacific']]: 
    remove_pct(us_census[race])
    us_census[race] = pd.to_numeric(us_census[race])

us_census['Pacific'] = us_census['Pacific'].fillna(100 - us_census['Hispanic'] - us_census['White'] - us_census['Black'] - us_census['Native'] - us_census['Asian'])

us_census.head()

for race in us_census[['Hispanic', 'White', 'Black', 'Native', 'Asian', 'Pacific']]:
    plt.hist(us_census[race])
    plt.title("Histogram of the pct of {} people per state".format(race))
    plt.xlabel("Percentage")
    plt.ylabel("Frequency")
    plt.show()

# %% [markdown]
# ## Get Creative

# %% [markdown]
# 15. Phew. You've definitely impressed your boss on your first day of work.
#
#     But is there a way you really convey the power of pandas and Python over the drudgery of `csv` and Excel?
#
#     Try to make some more interesting graphs to show your boss, and the world! You may need to clean the data even more to do it, or the cleaning you have already done may give you the ease of manipulation you've been searching for.

# %%
for race in us_census[['Hispanic', 'White', 'Black', 'Native', 'Asian', 'Pacific']]:
    plt.scatter(us_census[race], us_census['Income'], c='green')
    plt.title("Scatterplot of Income vs. the pct of {} people per state".format(race))
    plt.xlabel("Percentage of {} people".format(race))
    plt.ylabel("Income")
    plt.show()
